# %%
from bs4 import BeautifulSoup as BS
from bokeh.plotting import figure, show 
import urllib.request
import pandas as pd
import numpy as np
import re as r
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# %%
# Define URL and datframe
request = urllib.request.Request('https://en.wikipedia.org/wiki/List_of_deadly_earthquakes_since_1900')
result = urllib.request.urlopen(request)
resulttext = result.read()

# %%
# pulling data from HTML
soup = BS(resulttext, 'html.parser')

# %%
# prettifying the soup
#print(soup.prettify)

# %%
# finding particular table in the soup
data = []
table = soup.find('table', "sortable wikitable")

# %%
# Iterate through your table, grab each row, and pull the < th > and < td > elements into a dataset
table = table.find_all('tr')
for row in table:
    cells = row.find_all('td')
    cells = [ele.text.strip() for ele in cells]
    data.append(cells)

# %%
# Define data frame and its field names and remove and extraneous records
quake_df = pd.DataFrame(data)
quake_df.drop(0, inplace=True)
quake_df = quake_df.rename(columns={0:'Origin', 1:'Country', 2:'Lat', 3:'Long', 4:'Depth', 5:'Magnitude', 6:'Secondary Effects', 7:'PDE_Shaking', 8:'PDE_Total', 9:'Utsu_Total', 10:'EM_DAT_Total', 11: 'Other'})

# %%
# Replace empty strings with NaN
quake_df = quake_df.apply(lambda x: x.str.strip()).replace('', np.nan)

# %%
# Remove the footnotes from the 'Other Source Deaths' column
quake_df['Other'] = quake_df.Other.str.replace(r'+','')
quake_df['Other'] = quake_df.Other.str.replace(r',','')
quake_df['Other'] = quake_df.Other.str.extract('(\d+)', expand = True)
quake_df['EM_DAT_Total'] = quake_df.EM_DAT_Total.str.extract('(\d+)', expand = True)

# %%
# Remove the footnotes from the 'Country' column
quake_df['Country'] = quake_df.Country.str.replace(r'\(.*','')
quake_df['Country'] = quake_df.Country.str.replace(r'\,.+', '')
quake_df['Country'] = quake_df.Country.str.replace(r'\s+$', '')

# %%
# convert magnitude to numeric
quake_df['Magnitude'] = quake_df.Magnitude.str.extract('(\d\.\d)', expand = True)

# %%
# create the death column
#quake_df[['PDE_Total', 'Utsu_Total', 'EM_DAT_Total', 'Other']] = quake_df[['PDE_Total', 'Utsu_Total', 'EM_DAT_Total', 'Other']].fillna(-1)
quake_df['PDE_Total'] = quake_df['PDE_Total'].astype(float)
quake_df['Utsu_Total'] = quake_df['Utsu_Total'].astype(float)
quake_df['EM_DAT_Total']= quake_df['EM_DAT_Total'].astype(float)
quake_df['Other'] = quake_df['Other'].astype(float)

# %%
quake_df['Deaths'] = quake_df[['EM_DAT_Total','Utsu_Total','PDE_Total','Other']].apply(np.max, axis=1)

# %%
#quake_df[['EM_DAT_Total','Utsu_Total','PDE_Total','Other', 'Deaths']]=quake_df[['EM_DAT_Total','Utsu_Total','PDE_Total','Other', 'Deaths']].replace(-1.0,np.NaN)
quake_df
# Out:
#                 Origin            Country      Lat      Long Depth Magnitude  \
# 1     1900-05-11 17:23              Japan   38.700   141.100     5       7.0
# 2     1900-07-12 06:25             Turkey   40.300    43.100   NaN       5.9
# 3     1900-10-29 09:11          Venezuela   11.000   -66.000     0       7.7
# 4     1901-02-15 00:00              China   26.000   100.100     0       6.5
# 5     1901-03-31 07:11           Bulgaria   43.400    28.700   NaN       6.4
# 6     1901-08-09 09:23              Japan   40.500   142.500    35       7.2
# 7     1901-11-15 20:15        New Zealand  -43.000   173.000     0       6.8
# 8     1902-01-30 14:01              Japan   40.500   141.300    35       6.9
# 9     1902-02-13 09:39         Azerbaijan   40.700    48.600    15       6.9
# 10    1902-03-09 07:46             Turkey   40.700    33.600   NaN       5.5
# 11    1902-04-19 02:23          Guatemala   14.000   -91.000     0       7.5
# 12    1902-07-03 15:36              China   43.200   129.600    20       6.7
# 13    1902-08-22 03:00              China   40.000    77.000     0       7.7
# 14          1902-09-19          Australia  -35.000   138.000     2       6.0
# 15    1902-12-16 05:07         Uzbekistan   40.800    72.300     9       6.4
# 16    1903-03-29 22:30  Judea and Samaria   32.200    35.300   NaN       5.7
# 17          1903-04-28             Turkey    39.14     42.65   NaN       7.0
# 18    1903-05-28 03:58             Turkey   40.900    42.700   NaN       5.8
# 19    1903-08-11 04:32             Greece   36.360    22.970    80       8.3
# 20    1903-09-25 01:20               Iran   35.200    58.200   NaN       6.5
# 21    1904-04-24 06:39             Taiwan   23.500   120.500   NaN       6.0
# 22    1904-08-11 05:56             Greece   37.750    27.000    10       6.2
# 23    1904-08-30 11:42              China   30.000   101.000     0       6.8
# 24    1904-11-05 20:25             Taiwan   23.500   120.300   NaN       6.3
# 25    1905-04-04 00:50              India   33.000    76.000     0       7.8
# 26    1905-06-01 04:42            Albania   42.100    19.600    20       6.6
# 27    1905-06-02 05:39              Japan   34.100   132.500    55       7.0
# 28    1905-09-08 01:43              Italy   39.000    16.000     0       6.8
# 29    1905-11-08 22:06             Greece   40.000    24.000     0       6.8
# 30    1906-01-31 15:36            Ecuador    1.000   -81.500     0       8.8
# ...                ...                ...      ...       ...   ...       ...
# 1311  2008-05-25 08:21              China   32.560   105.423    18       6.1
# 1312  2008-06-06 20:02            Algeria   35.883    -0.658     4       5.5
# 1313  2008-06-08 12:25             Greece   37.963    21.525    16       6.4
# 1314  2008-06-13 23:43              Japan   39.030   140.881     7       6.9
# 1315  2008-06-17 05:51              China   32.761   105.554    10       4.8
# 1316  2008-07-15 03:26             Greece   35.983    27.785    68       6.4
# 1317  2008-08-21 12:24              China     25.1      97.9   NaN       5.9
# 1318   2008-08-30 8:30              China     26.0     101.9    10       5.7
# 1319  2008-10-05 15:52         Kyrgyzstan   39.515    73.768  27.6       6.9
# 1320  2008-10-06 16:30              China      NaN       NaN   NaN       6.4
# 1321  2008-10-28 23:09           Pakistan      NaN       NaN   NaN       6.4
# 1322  2009-01-08 19:21         Costa Rica  10.3962  -84.0281    48       6.1
# 1323  2009-04-06 03:32              Italy   42.334    13.334   8.8       6.2
# 1324  2009-07-09 11:19              China      NaN       NaN   NaN       5.7
# 1325  2009-08-10 20:07              Japan      NaN       NaN   NaN       6.4
# 1326  2009-09-02 07:55          Indonesia      NaN       NaN   NaN       7.0
# 1327  2009-09-29 17:48              Samoa      NaN       NaN   8.1       8.1
# 1328  2009-09-30 10:16          Indonesia      NaN       NaN   NaN       7.6
# 1329  2010-01-12 17:00              Haiti   18.457   -72.533    13       7.0
# 1330  2010-02-27 06:34              Chile  -35.846   -72.719    35       8.8
# 1331  2010-03-08 02:32             Turkey      NaN       NaN   NaN       6.1
# 1332  2010-03-11 14:39              Chile      NaN       NaN   NaN       6.9
# 1333  2010-04-14 23:49              China      NaN       NaN   NaN       6.9
# 1334  2011-02-21 23:51        New Zealand      NaN       NaN   NaN       6.3
# 1335  2011-03-10 04:58              China      NaN       NaN   NaN       5.4
# 1336  2011-03-11 14:46              Japan   38.322   142.369  24.4       9.0
# 1337  2011-03-24 20:25              Burma      NaN       NaN   NaN       6.8
# 1338  2011-04-07 14:32              Japan     38.2     140.0  66.0       7.1
# 1339  2011-09-18 12:40              India   27.723    88.064  19.7       6.9
# 1340  2011-09-23 10:41             Turkey     38.6      43.5   7.2       7.1
#
#      Secondary Effects PDE_Shaking  PDE_Total  Utsu_Total  EM_DAT_Total  \
# 1                  NaN         NaN        NaN         NaN           NaN
# 2                  NaN         NaN        NaN       140.0           NaN
# 3                  NaN         NaN        NaN         NaN           NaN
# 4                  NaN         NaN        NaN         NaN           NaN
# 5                  NaN         NaN        NaN         4.0           NaN
# 6                    T         NaN        NaN         NaN           NaN
# 7                  NaN         NaN        NaN         1.0           NaN
# 8                  NaN         NaN        NaN         1.0           NaN
# 9                  NaN         NaN        NaN        86.0           NaN
# 10                 NaN         NaN        NaN         4.0           NaN
# 11                 NaN         NaN        NaN      2000.0        2000.0
# 12                 NaN         NaN        NaN         NaN           NaN
# 13                 NaN         NaN        NaN      5650.0           NaN
# 14                 NaN         NaN        NaN         2.0           NaN
# 15                 NaN         NaN        NaN      4725.0           NaN
# 16                 NaN         NaN        NaN        20.0           NaN
# 17                 NaN         NaN        NaN         NaN           NaN
# 18                 NaN         NaN        NaN      1000.0           NaN
# 19                 NaN         NaN        NaN         2.0           NaN
# 20                 NaN         NaN        NaN       200.0           NaN
# 21                 NaN         NaN        NaN         3.0           NaN
# 22                 NaN         NaN        NaN         4.0           NaN
# 23                 NaN         NaN        NaN       565.0           NaN
# 24                 NaN         NaN        NaN       145.0           NaN
# 25                 NaN         NaN        NaN     20000.0       20000.0
# 26                 NaN         NaN        NaN       120.0           NaN
# 27                 NaN         NaN        NaN        11.0           NaN
# 28                   T         NaN        NaN       557.0        2500.0
# 29                 NaN         NaN        NaN         NaN           NaN
# 30                   T         NaN        NaN      1000.0         400.0
# ...                ...         ...        ...         ...           ...
# 1311                 L           8        8.0         NaN           NaN
# 1312               NaN           0        1.0         NaN           NaN
# 1313               NaN           2        2.0         NaN           2.0
# 1314                 L          13       13.0         NaN          13.0
# 1315               NaN           2        2.0         NaN           NaN
# 1316               NaN         NaN        NaN         NaN           NaN
# 1317               NaN         NaN        NaN         NaN           NaN
# 1318               NaN         NaN        NaN         NaN           NaN
# 1319               NaN         NaN        NaN         NaN           NaN
# 1320               NaN         NaN        NaN         NaN           NaN
# 1321               NaN         NaN        NaN         NaN           NaN
# 1322                 L         NaN        NaN         NaN           NaN
# 1323               NaN         NaN        NaN         NaN           NaN
# 1324               NaN         NaN        NaN         NaN           NaN
# 1325               NaN         NaN        NaN         NaN           NaN
# 1326               NaN         NaN        NaN         NaN           NaN
# 1327               NaN         NaN        NaN         NaN           NaN
# 1328               NaN         NaN        NaN         NaN           NaN
# 1329               NaN         NaN        NaN         NaN           NaN
# 1330                 T         NaN        NaN         NaN           NaN
# 1331               NaN         NaN        NaN         NaN           NaN
# 1332                 L         NaN        NaN         NaN           NaN
# 1333                 L         NaN        NaN         NaN           NaN
# 1334                Lq         NaN        NaN         NaN           NaN
# 1335               NaN         NaN        NaN         NaN           NaN
# 1336                 T         NaN        NaN         NaN           NaN
# 1337               NaN         NaN        NaN         NaN           NaN
# 1338               NaN         NaN        NaN         NaN           NaN
# 1339                 L         NaN        NaN         NaN           NaN
# 1340               NaN         NaN        NaN         NaN           NaN
#
#          Other    Deaths
# 1          NaN       NaN
# 2          NaN     140.0
# 3          NaN       NaN
# 4          NaN       NaN
# 5          NaN       4.0
# 6          NaN       NaN
# 7          NaN       1.0
# 8          NaN       1.0
# 9          NaN      86.0
# 10         NaN       4.0
# 11         NaN    2000.0
# 12         NaN       NaN
# 13         NaN    5650.0
# 14         NaN       2.0
# 15         NaN    4725.0
# 16         NaN      20.0
# 17      3500.0    3500.0
# 18         NaN    1000.0
# 19         NaN       2.0
# 20         NaN     200.0
# 21         NaN       3.0
# 22         NaN       4.0
# 23         NaN     565.0
# 24         NaN     145.0
# 25         NaN   20000.0
# 26         NaN     120.0
# 27         NaN      11.0
# 28         NaN    2500.0
# 29         NaN       NaN
# 30         NaN    1000.0
# ...        ...       ...
# 1311       NaN       8.0
# 1312       NaN       1.0
# 1313       NaN       2.0
# 1314       NaN      13.0
# 1315       NaN       2.0
# 1316       NaN       NaN
# 1317       NaN       NaN
# 1318      41.0      41.0
# 1319      60.0      60.0
# 1320       NaN       NaN
# 1321     215.0     215.0
# 1322      34.0      34.0
# 1323     295.0     295.0
# 1324       NaN       NaN
# 1325       1.0       1.0
# 1326      79.0      79.0
# 1327     189.0     189.0
# 1328    1115.0    1115.0
# 1329  222517.0  222517.0
# 1330     521.0     521.0
# 1331      42.0      42.0
# 1332       1.0       1.0
# 1333    2698.0    2698.0
# 1334     181.0     181.0
# 1335       NaN       NaN
# 1336   15894.0   15894.0
# 1337     150.0     150.0
# 1338       NaN       NaN
# 1339     111.0     111.0
# 1340     601.0     601.0
#
# [1340 rows x 13 columns]

# %%
# Importing population density from wikipedia
data = pd.read_html("https://simple.wikipedia.org/wiki/List_of_countries_by_population_density", header = 0)

# %%
popdens = pd.DataFrame(data[0])

# %%
popdens.columns
# Out:
# Index(['Rank', 'Country / dependent territory', 'Population',
#        'Date last updated', 'Area (km2)', 'Area (mi2)', 'Density (/km2)',
#        'Density (/mi2)', 'Notes'],
#       dtype='object')

# %%
# Picking only 2 columns from the dataset
popdens = popdens[['Country / dependent territory', 'Density (/mi2)']]

# %%
# making column name consistent with the other dataset
popdens.columns = ['Country', 'Density']
popdens.head()
# Out:
#              Country Density
# 0      Macau (China)   48003
# 1             Monaco   43830
# 2          Singapore   18513
# 3  Hong Kong (China)   16444
# 4     Gibraltar (UK)   11808

# %%
#merging with quake_df data to get the density column
# NetmigIntmerge = pd.merge(UNmig1, UNInt1, how = 'inner', on=['Country', 'Year'])
quake_df_dens = pd.merge(quake_df,popdens, how = 'left', on = 'Country' )

# %%
quake_df_dens.head()
# Out:
#              Origin    Country     Lat     Long Depth Magnitude  \
# 0  1900-05-11 17:23      Japan  38.700  141.100     5       7.0
# 1  1900-07-12 06:25     Turkey  40.300   43.100   NaN       5.9
# 2  1900-10-29 09:11  Venezuela  11.000  -66.000     0       7.7
# 3  1901-02-15 00:00      China  26.000  100.100     0       6.5
# 4  1901-03-31 07:11   Bulgaria  43.400   28.700   NaN       6.4
#
#   Secondary Effects PDE_Shaking  PDE_Total  Utsu_Total  EM_DAT_Total  Other  \
# 0               NaN         NaN        NaN         NaN           NaN    NaN
# 1               NaN         NaN        NaN       140.0           NaN    NaN
# 2               NaN         NaN        NaN         NaN           NaN    NaN
# 3               NaN         NaN        NaN         NaN           NaN    NaN
# 4               NaN         NaN        NaN         4.0           NaN    NaN
#
#    Deaths Density
# 0     NaN     873
# 1   140.0     241
# 2     NaN      91
# 3     NaN     373
# 4     4.0     171

# %%
# Making a categorial variable based on magnitude
def severity (value):
    if value >= 6:
        return 'Devastating'
    elif  4 < value < 6:
        return 'Moderate'
    elif 2 < value <= 4 :
        return 'Mild'
    else:
        return 'Minuscle'

# %%
quake_df_dens['Magnitude']= quake_df_dens.Magnitude.apply(float)
quake_df_dens['Intensity']= quake_df_dens['Magnitude'].apply(severity)

# %%
quake_df_dens.head()
# Out:
#              Origin    Country     Lat     Long Depth  Magnitude  \
# 0  1900-05-11 17:23      Japan  38.700  141.100     5        7.0
# 1  1900-07-12 06:25     Turkey  40.300   43.100   NaN        5.9
# 2  1900-10-29 09:11  Venezuela  11.000  -66.000     0        7.7
# 3  1901-02-15 00:00      China  26.000  100.100     0        6.5
# 4  1901-03-31 07:11   Bulgaria  43.400   28.700   NaN        6.4
#
#   Secondary Effects PDE_Shaking  PDE_Total  Utsu_Total  EM_DAT_Total  Other  \
# 0               NaN         NaN        NaN         NaN           NaN    NaN
# 1               NaN         NaN        NaN       140.0           NaN    NaN
# 2               NaN         NaN        NaN         NaN           NaN    NaN
# 3               NaN         NaN        NaN         NaN           NaN    NaN
# 4               NaN         NaN        NaN         4.0           NaN    NaN
#
#    Deaths Density    Intensity
# 0     NaN     873  Devastating
# 1   140.0     241     Moderate
# 2     NaN      91  Devastating
# 3     NaN     373  Devastating
# 4     4.0     171  Devastating

# %%
# making density column as float
quake_df_dens['Density'] = quake_df_dens['Density'].astype(float)

# %%
# making a density function
def dens (value):
    if value >= 750:
        return 'Huge'
    elif  500 < value < 750:
        return 'Bearable'
    elif 250 < value <= 500 :
        return 'Easy'
    else:
        return 'Sparse'

# %%
 quake_df_dens['Density_cat']= quake_df_dens['Density'].apply(dens)

# %%
# quake_df_dens.head()

# %%
# looking for the effect of Intensity and Density on deaths
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
sns.swarmplot(x='Intensity', y= 'Deaths', data = quake_df_dens)

# %%
# looking for the effect of Intensity and Density on deaths
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
sns.swarmplot(x='Density_cat', y= 'Deaths', data = quake_df_dens)

# %%
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
sns.violinplot(x='Density_cat', y= 'Deaths', data = quake_df_dens)

# %%
quake_df_dens.plot(kind="scatter",     # Create a scatterplot
              x='Magnitude',          
              y='Deaths',  
              figsize=(10,10),
              ylim=(0,2000))

# %%
from bokeh.io import output_file, show
plot = figure()
plot.circle(quake_df_dens['Magnitude'], quake_df['Deaths'], size =10)
output_file('magdeath.html')
show(plot)

# %%
plot = figure()
plot.circle(quake_df_dens['Density'], quake_df_dens['Deaths'], size =10)
output_file('magdeath1.html')
show(plot)

# %%
# importing the GDP data
GDPCtry = pd.read_excel('/Users/paulomartinez/Git/data-question-3-silent_fireballs/IMFGDP2017.xlsx')

# %%
GDPdf = pd.DataFrame(GDPCtry)

# %%
GDPdf.head()
# Out:
#                Country        GDP
# 0          Afghanistan    572.163
# 1              Albania   4520.268
# 2              Algeria   4225.004
# 3               Angola   4401.432
# 4  Antigua and Barbuda  16826.192

# %%
GDPdf.query('GDP >= 75000')
# Out:
#          Country         GDP
# 99    Luxembourg  107708.217
# 100    Macao SAR   79563.556
# 164  Switzerland   80836.658

# %%
GDPdf.columns
# Out:
# Index(['Country', 'GDP'], dtype='object')

# %%
# merging GDP data with the data frame
quake_df_dens_GDP = pd.merge(quake_df_dens,GDPdf, how = 'left', on = 'Country' )

# %%
# quake_df_dens_GDP

# %%
quake_df_dens_GDP['GDP'] = quake_df_dens_GDP['GDP'].astype(float)

# %%
# making a GDP function
def Gross (value):
    if value >= 50000:
        return 'Very_rich'
    elif  25000 < value < 50000:
        return 'Rich'
    elif 10000 < value <= 25000 :
        return 'Developing'
    else:
        return 'Poor'

# %%
 quake_df_dens_GDP['GDP_cat']= quake_df_dens_GDP['GDP'].apply(Gross)

# %%
quake_df_dens_GDP.head()
# Out:
#              Origin    Country     Lat     Long Depth  Magnitude  \
# 0  1900-05-11 17:23      Japan  38.700  141.100     5        7.0
# 1  1900-07-12 06:25     Turkey  40.300   43.100   NaN        5.9
# 2  1900-10-29 09:11  Venezuela  11.000  -66.000     0        7.7
# 3  1901-02-15 00:00      China  26.000  100.100     0        6.5
# 4  1901-03-31 07:11   Bulgaria  43.400   28.700   NaN        6.4
#
#   Secondary Effects PDE_Shaking  PDE_Total  Utsu_Total  EM_DAT_Total  Other  \
# 0               NaN         NaN        NaN         NaN           NaN    NaN
# 1               NaN         NaN        NaN       140.0           NaN    NaN
# 2               NaN         NaN        NaN         NaN           NaN    NaN
# 3               NaN         NaN        NaN         NaN           NaN    NaN
# 4               NaN         NaN        NaN         4.0           NaN    NaN
#
#    Deaths  Density    Intensity Density_cat        GDP     GDP_cat
# 0     NaN    873.0  Devastating        Huge  38550.089        Rich
# 1   140.0    241.0     Moderate      Sparse  10434.023  Developing
# 2     NaN     91.0  Devastating      Sparse   6850.121        Poor
# 3     NaN    373.0  Devastating        Easy   8582.940        Poor
# 4     4.0    171.0  Devastating      Sparse   7923.967        Poor

# %%
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
sns.swarmplot(x='GDP_cat', y= 'Deaths', data = quake_df_dens_GDP)

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
plt.scatter(quake_df_dens_GDP.Magnitude, quake_df_dens_GDP.Deaths)

# %%
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
sns.swarmplot(x='Intensity', y= 'Deaths', hue = 'GDP_cat',data = quake_df_dens_GDP)

# %%
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
sns.swarmplot(x='Intensity', y= 'Deaths', hue = 'Density_cat',data = quake_df_dens_GDP)

# %%
fig=plt.figure(figsize=(12, 10), dpi= 80, facecolor='w', edgecolor='k')
sns.factorplot(x="Intensity", y="Deaths", hue="GDP_cat", col="Density_cat", data=quake_df_dens_GDP, kind="swarm")

# %%
from bokeh.io import output_file, show
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, Range1d, PanTool, WheelZoomTool, BoxSelectTool
)

# %%
source = ColumnDataSource(quake_df_dens_GDP)

circle = Circle(x="Long", y="Lat", size=15, fill_color="blue", fill_alpha=0.8, line_color=None)
plot.add_glyph(source, circle)

plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())
output_file("gmap_plot.html")
show(plot)

# %%
# Making date time object out of origin
quake_df_dens_GDP['Year'] = pd.DatetimeIndex(quake_df_dens_GDP['Origin']).year
quake_df_dens_GDP.head()
# Out:
#              Origin    Country     Lat     Long Depth  Magnitude  \
# 0  1900-05-11 17:23      Japan  38.700  141.100     5        7.0
# 1  1900-07-12 06:25     Turkey  40.300   43.100   NaN        5.9
# 2  1900-10-29 09:11  Venezuela  11.000  -66.000     0        7.7
# 3  1901-02-15 00:00      China  26.000  100.100     0        6.5
# 4  1901-03-31 07:11   Bulgaria  43.400   28.700   NaN        6.4
#
#   Secondary Effects PDE_Shaking  PDE_Total  Utsu_Total  EM_DAT_Total  Other  \
# 0               NaN         NaN        NaN         NaN           NaN    NaN
# 1               NaN         NaN        NaN       140.0           NaN    NaN
# 2               NaN         NaN        NaN         NaN           NaN    NaN
# 3               NaN         NaN        NaN         NaN           NaN    NaN
# 4               NaN         NaN        NaN         4.0           NaN    NaN
#
#    Deaths  Density    Intensity Density_cat        GDP     GDP_cat  Year
# 0     NaN    873.0  Devastating        Huge  38550.089        Rich  1900
# 1   140.0    241.0     Moderate      Sparse  10434.023  Developing  1900
# 2     NaN     91.0  Devastating      Sparse   6850.121        Poor  1900
# 3     NaN    373.0  Devastating        Easy   8582.940        Poor  1901
# 4     4.0    171.0  Devastating      Sparse   7923.967        Poor  1901

# %%
fig=plt.figure(figsize=(12, 10), dpi= 80, facecolor='w', edgecolor='k')
sns.factorplot(x="Year", y="Deaths", hue="GDP_cat", col="Intensity", data=quake_df_dens_GDP, kind="swarm")

# %% [markdown]
# m = Basemap(projection = ‘mill’, llcrnrlat = -90, urcrnrlat = 90, llcrnrlon=-180, urcrnrlon=180, resolution=‘h’) #C for crude, l for lower for US llgrnrlat = -60
# m.drawcoastlines()
# m.drawcountries()
# m.fillcontinents(color = ‘#04bA3’, lake_color =‘#FFFFFF’)
# m.drawmapboundary(fill_color = ‘#FFFFFF’)
# plt.title(‘hbjs’)
# x,y = m(lon, lat)
# m.plot(x,y, ‘r0’, markersize =10, alpha = 0.5)
# plt.show()

# %%
quake_df_dens_GDP['Long'] = quake_df_dens_GDP['Long'].str.replace('?', '')
quake_df_dens_GDP['Long'] = quake_df_dens_GDP['Long'].astype(str)
quake_df_dens_GDP['Long'] = quake_df_dens_GDP['Long'].apply(lambda x: x.strip()).replace('', np.nan)

#quake_df_dens_GDP['Lat'] = quake_df_dens_GDP['Lat'].str.replace('??', '')

# %%
quake_df_dens_GDP['Lat'] = quake_df_dens_GDP['Lat'].astype(str)
quake_df_dens_GDP['Lat'] = quake_df_dens_GDP['Lat'].str.replace('?', '')
quake_df_dens_GDP['Lat'] = quake_df_dens_GDP['Lat'].str.replace('?', '')
quake_df_dens_GDP['Lat'] = quake_df_dens_GDP['Lat'].apply(lambda x: x.strip()).replace('', np.nan)

# %%
# making a list for lattitude and longitude
quake_df_dens_GDP['Long'] = quake_df_dens_GDP['Long'].astype(float)
quake_df_dens_GDP['Lat'] = quake_df_dens_GDP['Lat'].astype(float)
lon = quake_df_dens_GDP['Long'].tolist()
lat = quake_df_dens_GDP['Lat'].tolist()

# %%
fig=plt.figure(figsize=(16, 12), dpi= 80, facecolor='w', edgecolor='k')
m = Basemap(projection='mill',llcrnrlat=-90,urcrnrlat=90,\
            llcrnrlon=-180,urcrnrlon=180,resolution='c')
m.drawcoastlines()
m.fillcontinents(color='grey',lake_color='#FFFFFF')
m.drawmapboundary(fill_color='#FFFFFF')
x,y = m(lon,lat)
m.plot(x,y, 'bx')
plt.title("Quick Basemap Example!")
plt.show()
